# %% [markdown]
# <a href="https://colab.research.google.com/github/wanderrbrito/Challenge_AluraStrore/blob/main/Aula_02_Numpy_para_Data_Science_pratica.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np

# %%
arquivo = '/content/sample_data/apples_ts.csv'

# %%
dados = np.loadtxt(arquivo, delimiter=',', usecols=np.arange(1,88,1))

# %%
# Informações do array
print('Dimensoes:', dados.ndim)
print('Quantidade de elementos:', dados.size)
print('Formato:', dados.shape[0], 'linhas',dados.shape[1], 'Colunas')
# Out:
# Dimensoes: 2
# Quantidade de elementos: 522
# Formato: 6 linhas 87 Colunas

# %%
dados_transposto = dados.T
dados_transposto
